# %% [markdown]
# ## NYC complaints 311 Calls
#
# In this notebook we will exploit Pandas to perform data analysis on a dataset of calls to 311 (municipal calls, not emergency) in the New York City area.
#
# Download the data from [here](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9) (Go to Export -> CSV).

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# First, let's load the data. It will take some time...

# %%
complaints = pd.read_csv('data/311_Service_Requests_from_2010_to_Present.csv')
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (8,17,31,32,33,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
complaints.head()

# Same would have been with
# complaints[:5]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    30799952  06/08/2015 03:44:36 PM  06/09/2015 09:38:39 AM    DOT
# 1    30799953  06/08/2015 10:43:29 AM  06/09/2015 04:09:12 PM    DOT
# 2    30799954  06/08/2015 02:26:39 PM  06/16/2015 05:42:07 PM    DOT
# 3    30799956  06/08/2015 08:21:03 PM  06/09/2015 04:54:48 AM   NYPD
# 4    30799957  06/08/2015 01:35:47 PM  06/16/2015 05:45:21 PM    DOT
#
#                        Agency Name      Complaint Type        Descriptor  \
# 0     Department of Transportation    Street Condition           Cave-in
# 1     Department of Transportation    Street Condition           Cave-in
# 2     Department of Transportation    Street Condition           Cave-in
# 3  New York City Police Department  Noise - Commercial  Banging/Pounding
# 4     Department of Transportation    Street Condition           Cave-in
#
#       Location Type Incident Zip  Incident Address  \
# 0            Street        10309               NaN
# 1            Street        10456     TELLER AVENUE
# 2            Street        11357  169-32 23 AVENUE
# 3  Store/Commercial        11385   60-20 68 AVENUE
# 4            Street        11377   43-21 53 STREET
#
#                     ...                    Vehicle Type Taxi Company Borough  \
# 0                   ...                             NaN                  NaN
# 1                   ...                             NaN                  NaN
# 2                   ...                             NaN                  NaN
# 3                   ...                             NaN                  NaN
# 4                   ...                             NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0       NaN                    NaN  40.518768 -74.210625
# 1       NaN                    NaN  40.827049 -73.915040
# 2       NaN                    NaN  40.776298 -73.794467
# 3       NaN                    NaN  40.704292 -73.899305
# 4       NaN                    NaN  40.743912 -73.911613
#
#                                   Location
# 0  (40.51876750770238, -74.21062507288462)
# 1  (40.82704935343712, -73.91503956914566)
# 2   (40.77629832421394, -73.7944673063674)
# 3   (40.7042917941881, -73.89930496178219)
# 4  (40.74391151928502, -73.91161254468453)
#
# [5 rows x 41 columns]

# %%
complaints['Complaint Type'].unique()
# Out:
# array(['Street Condition', 'Noise - Commercial',
#        'DOF Property - Owner Issue', 'Highway Condition',
#        'Benefit Card Replacement', 'DOF Parking - Payment Issue',
#        'Air Quality', 'Blocked Driveway', 'Indoor Air Quality',
#        'Sidewalk Condition', 'Asbestos',
#        'Missed Collection (All Materials)',
#        'Root/Sewer/Sidewalk Condition', 'Building/Use', 'DOOR/WINDOW',
#        'Broken Muni Meter', 'ELECTRIC', 'Curb Condition',
#        'Sanitation Condition', 'Noise', 'Consumer Complaint',
#        'New Tree Request', 'Housing - Low Income Senior',
#        'Maintenance or Facility', 'Construction', 'Noise - Helicopter',
#        'DOF Parking - DMV Clearance', 'Elevator', 'Damaged Tree',
#        'PAINT/PLASTER', 'Street Light Condition', 'Noise - Vehicle',
#        'Overgrown Tree/Branches', 'Water System', 'Noise - Residential',
#        'SCRIE', 'Hazardous Materials', 'HEAT/HOT WATER',
#        'Derelict Vehicles', 'DOF Property - Property Value',
#        'Food Establishment', 'DOF Parking - Request Copy',
#        'Street Sign - Damaged', 'General Construction/Plumbing',
#        'Other Enforcement', 'Traffic Signal Condition', 'Graffiti',
#        'Traffic', 'Animal Abuse', 'DOF Property - Reduction Issue',
#        'Sewer', 'DOF Property - Request Copy', 'Derelict Vehicle',
#        'Water Conservation', 'Illegal Parking', 'Homeless Encampment',
#        'Rodent', 'Sweeping/Inadequate', 'Noise - Street/Sidewalk',
#        'Noise - House of Worship', 'Industrial Waste',
#        'Homeless Person Assistance', 'Taxi Compliment',
#        'Animal in a Park', 'Street Sign - Missing', 'SAFETY',
#        'Taxi Report', 'UNSANITARY CONDITION', 'Indoor Sewage',
#        'Dirty Conditions', 'Vacant Lot', 'Non-Emergency Police Matter',
#        'Dead Tree', 'Recycling Enforcement', 'Vending', 'WATER LEAK',
#        'Overflowing Litter Baskets', 'Street Sign - Dangling',
#        'Violation of Park Rules', 'Bus Stop Shelter Placement',
#        'Litter Basket / Request', 'GENERAL', 'Found Property', 'Plumbing',
#        'Standing Water', 'DOF Property - Payment Issue', 'Water Quality',
#        'DPR Internal', 'Elder Abuse', 'Noise - Park', 'Lead',
#        'Special Projects Inspection Team (SPIT)', 'School Maintenance',
#        'APPLIANCE', 'Tanning', 'Housing Options', 'PLUMBING',
#        'Bike Rack Condition', 'Drinking', 'Illegal Animal Kept as Pet',
#        'Sweeping/Missed', 'DOF Parking - Tax Exemption',
#        'Derelict Bicycle', 'ELEVATOR', 'Food Poisoning',
#        'Broken Parking Meter', 'Illegal Tree Damage', 'Taxi Complaint',
#        'Smoking', 'Unsanitary Animal Pvt Property',
#        'DOF Parking - Request Status', 'For Hire Vehicle Report',
#        'Urinating in Public', 'Public Payphone Complaint',
#        'Home Delivered Meal - Missed Delivery', 'Disorderly Youth',
#        'Ferry Complaint', 'Mold', 'Bridge Condition', 'Unleashed Dog',
#        'Ferry Inquiry', 'Bus Stop Shelter Complaint',
#        'Senior Center Complaint', 'Plant', 'Bike/Roller/Skate Chronic',
#        'Overflowing Recycling Baskets', 'Home Delivered Meal Complaint',
#        'City Vehicle Placard Complaint',
#        'Investigations and Discipline (IAD)',
#        'For Hire Vehicle Complaint', 'Cranes and Derricks',
#        'Illegal Fireworks', 'Collection Truck Noise', 'FLOORING/STAIRS',
#        'Panhandling', 'Highway Sign - Missing', "Alzheimer's Care",
#        'Case Management Agency Complaint', 'Home Care Provider Complaint',
#        'Highway Sign - Damaged', 'Bereavement Support Group',
#        'Posting Advertisement', 'Beach/Pool/Sauna Complaint',
#        'Miscellaneous Categories', 'BEST/Site Safety',
#        'Harboring Bees/Wasps', 'DOF Property - RPIE Issue', 'Poison Ivy',
#        'Stalled Sites', 'Tattooing', 'Municipal Parking Facility',
#        'Boilers', 'Unsanitary Animal Facility',
#        'Animal Facility - No Permit', 'Calorie Labeling', 'Window Guard',
#        'OUTSIDE BUILDING', 'Squeegee', 'Public Toilet',
#        'Tunnel Condition', 'Adopt-A-Basket',
#        'Unsanitary Pigeon Condition', 'Drinking Water',
#        'Illegal Animal Sold', 'Radioactive Material',
#        'Emergency Response Team (ERT)', 'ATF', 'Bottled Water',
#        'Electrical', 'FATF', 'Scaffold Safety', 'Highway Sign - Dangling',
#        'Ferry Permit', 'DHS Income Savings Requirement',
#        'HPD Literature Request', 'Special Natural Area District (SNAD)',
#        'Lifeguard', 'X-Ray Machine/Equipment',
#        'DOF Property - City Rebate', 'OEM Literature Request',
#        'Parking Card', 'Foam Ban Enforcement', 'SRDE',
#        'DCA / DOH New License Application Request',
#        'Legal Services Provider Complaint', 'Building Condition',
#        'Construction Safety Enforcement', 'VACANT APARTMENT',
#        'Transportation Provider Complaint', 'Non-Residential Heat',
#        'Advocate-SCRIE/DRIE', 'Advocate-Personal Exemptions',
#        'Advocate-Prop Class Incorrect', 'Advocate-Commercial Exemptions',
#        'Taxpayer Advocate Inquiry', 'Snow', 'Advocate - Other',
#        'Interior Demo', 'DOF Property - Update Account', 'Day Care',
#        'Advocate - RPIE', 'Research Questions',
#        'Advocate-Prop Refunds/Credits', 'Request Xmas Tree Collection',
#        'Advocate-Co-opCondo Abatement', 'DOR Literature Request',
#        'OEM Disabled Vehicle', 'Advocate-Property Value',
#        'Dead/Dying Tree', 'AGENCY', 'Advocate-UBT',
#        'Sweeping/Missed-Inadequate', 'Trans Fat',
#        'Asbestos/Garbage Nuisance', 'Mosquitoes', 'Forms', 'Facades',
#        'NORC Complaint', 'DRIE', 'Advocate-Business Tax', 'LinkNYC',
#        'Trapping Pigeon', 'LEAD', 'Drug Activity', 'Electronics Waste',
#        'MOLD', 'Cooling Tower', 'Pet Shop',
#        'Electronics Waste Appointment', 'Building Marshals office',
#        'Comments', 'CST', 'Question',
#        'Request Large Bulky Item Collection', 'Advocate - Lien', 'FCST',
#        'Advocate - Levy', 'DEP Street Condition',
#        'Select Message Type...', 'General Question',
#        'Homebound Evacuation 4', 'DEP Sidewalk Condition',
#        'Abandoned Vehicle', 'Lost Property', 'Animal-Abuse',
#        'Mobile Food Vendor', 'Green Taxi Complaint', 'Borough Office',
#        'HEATING', 'Water Maintenance', 'Single Occupancy Bathroom',
#        'Sustainability Enforcement', 'FHE', 'Forensic Engineering',
#        'NONCONST', 'Traffic/Illegal Parking', 'DHS Advantage - Tenant',
#        'DHS Advantage -Landlord/Broker', 'PAINT - PLASTER',
#        'GENERAL CONSTRUCTION', 'CONSTRUCTION', 'Eviction', 'Home Repair',
#        'Utility Program', 'Safety', 'DHS Advantage - Third Party',
#        'Health', 'HEAP Assistance', 'Discipline and Suspension',
#        'Teaching/Learning/Instruction', 'Weatherization',
#        'DOF Parking - Address Update', 'Parent Leadership',
#        'Portable Toilet', 'Registration and Transfers',
#        'No Child Left Behind', 'DOF Property - State Rebate',
#        'Summer Camp', 'SG-99', 'Noise Survey', 'Unlicensed Dog',
#        'Standpipe - Mechanical', 'DOF Literature Request',
#        'Hazardous Material', 'Special Operations', 'SNW', 'STRUCTURAL',
#        'Green Taxi Report', 'Executive Inspections', 'Injured Wildlife',
#        'Illegal Animal - Sold/Kept', 'Missed Collection',
#        'DEP Highway Condition', 'Unsanitary Condition',
#        'Dept of Investigations', 'Quality of Life',
#        'FHV Licensee Complaint', 'Dispatched Taxi Complaint',
#        'Advocate-Foreclosure', '$(sleep 11)', '%{4761*8506}',
#        'Misc. Comments);declare @q ...', '%c0%ae/%c0%ae/%c0%ae/%c0%ae...',
#        'Misc. Comments|ping -n 21 1...', 'file:///etc/passwd',
#        "(select load_file('\\\\\\\\615h...",
#        "Misc. Comments'(select*from...", 'hcvn1{{687*375}}gji51',
#        "Misc. Comments');declare @q...",
#        'Misc. Comments..\\..\\..\\..\\....', '\\windows\\win.ini',
#        '@(9313*3464)', "Misc. Comments'+sleep(20.to...",
#        "Misc. Comments'|ping -c 21 ...", 'file:///c:/windows/win.ini',
#        '%{(#dm=@ognl.OgnlContext@DE...', '../../../../../../../../../...',
#        "Misc. Comments' and '1618'=...", "Misc. Comments' and (select...",
#        'Misc. Comments  BCC:a5glxzf...', "Misc. Comments'+(select*fro...",
#        "Misc. Comments'+eval(compil...", '${3804*3137}',
#        '.../....///.../....///.../....', "Misc. Comments' and 6049=60...",
#        'http://g7orz5h9iu2sh6z332rj...', 'Misc. Comments&echo xjd...',
#        "{!xmlparser v='<!DOCTYPE...", 'MSOTHER',
#        'Misc. Comments&ping -n ...', 'Misc. Comments&nslookup...',
#        'Misc. Comments]]>><', '<odb xmlns:xi="http...',
#        'a\'a\\\'b"c>?>%}}%%...', '() { _; } >_', '"-->\'-->`-->&...',
#        '*)(!(objectClass=*)', '.../Misc. Comments', '/etc/passwd',
#        'Misc. Comments;declare @q v...', 'Misc. Comments|echo 3p7wexz...',
#        'c:\\windows\\win.ini Misc. Co...',
#        'nslookup -q=cname nneyfcxgy...', '*)(objectClass=*',
#        '.../...//.../...//.../...//...',
#        '...\\.\\...\\.\\...\\.\\...\\.\\......', '../WEB-INF/web.xml',
#        '1430*4963', 'g0oii1s4s5)(objectClass=*', "kawn''lcgv",
#        '../../../WEB-INF/web.xml;x=',
#        '..\\..\\..\\..\\..\\..\\..\\..\\..\\...',
#        "Misc. Comments'+(function()...", "Misc. Comments'.sleep(20).'",
#        "Misc. Comments';declare @q ...", 'Misc. Comments../../../../....',
#        "Misc. Comments69075347' or ...", '%2e%2e%5c%2e%2e%5c%2e%2e%5c...',
#        '(select extractvalue(xmltyp...', "Misc. Comments'||(select ex...",
#        "Misc. Comments88909845' or ...", 'Misc. Comments|ping -c 21 1...',
#        "Misc. Comments}}t2v95'/&quo...", '`sleep 11`',
#        'c:\\windows\\win.ini', 'idexf3mrb7)(!(objectClass=*)',
#        '%E5%98%8A%E5%98%8DX-Injecti...', '() { :;}; /bin/sleep 11',
#        '..././..././..././..././......', '../../../WEB-INF/web.xml',
#        '../../WEB-INF/web.xml;x=', './validate_form.php',
#        '/./validate_form.php', '.../.\\.../.\\.../.\\.../.\\......',
#        '../../WEB-INF/web.xml', "Misc. Comments%}dt2pq'/&quo...",
#        "Misc. Comments'", "Misc. Comments'+(select loa...",
#        "Misc. Comments',0)waitfor d...", "Misc. Comments47876391' or ...",
#        'Misc. Comments{${sleep(20)}}', 'qfix4${695*589}lixaf',
#        '%c0%ae/%c0%ae/WEB-INF/web.xml', '%c0%ae/WEB-INF/web.xml',
#        '...\\./...\\./...\\./...\\./......', '../WEB-INF/web.xml;x=',
#        "Misc. Comments' and '7835'=...", "Misc. Comments' and 7702=77...",
#        'Misc. Comments,(select*from...', "Misc. Comments52038737' or ...",
#        "eval(compile('for x in rang...", 'yw97y0gi2s',
#        '%2e%2e%2f%2e%2e%2f%2e%2e%2f...', '%2fetc%2fpasswd',
#        '%c0%ae/%c0%ae/%c0%ae/WEB-IN...', '() { :;}; /bin/sleep 0',
#        '../../../../WEB-INF/web.xml', '266dyrgvhg1egsyp2oq57axbm2s...',
#        "Misc. Comments' waitfor del...", "Misc. Comments')waitfor del...",
#        "Misc. Comments'|echo y9v6fc...", 'Misc. Commentseowljujfh8',
#        'Misc. Comments|nslookup -q=...', 'Misc. Comments\'"`0&amp...',
#        'Misc. Comments"', 'Misc. Comments"|ping -...',
#        'Misc. Comments"|echo 2...', 'Misc. Commentso0w3r%>xb6...',
#        'bcd9<!--esi-->1ggp&lt...', 'Employee Behavior', 'DSNY Spillage',
#        'General', 'Appliance', 'Taxi Licensee Complaint',
#        '<vlv xmlns="http://...', 'Misc. Comments>  BCC:bl0...',
#        'Internal Code', 'Outside Building', 'Water Leak', 'Electric',
#        'Fire Alarm - Modification', 'Fire Alarm - New System',
#        'Open Flame Permit', 'Rangehood', 'Public Assembly',
#        'Fire Alarm - Reinspection', 'Hazmat Storage/Use',
#        'Sprinkler - Mechanical', 'Public Assembly - Temporary',
#        'Gas Station Discharge Lines', 'Request Changes - A.S.P.',
#        'Fire Alarm - Replacement', 'Dispatched Taxi Compliment',
#        'Meals Home Delivery Required'], dtype=object)

# %%
complaints[['Complaint Type', 'Borough']][:10]
# complaints[:10][['Complaint Type', 'Borough']]
# Out:
#                 Complaint Type        Borough
# 0             Street Condition  STATEN ISLAND
# 1             Street Condition          BRONX
# 2             Street Condition         QUEENS
# 3           Noise - Commercial         QUEENS
# 4             Street Condition         QUEENS
# 5             Street Condition         QUEENS
# 6   DOF Property - Owner Issue      MANHATTAN
# 7            Highway Condition      MANHATTAN
# 8     Benefit Card Replacement    Unspecified
# 9  DOF Parking - Payment Issue    Unspecified

# %%
complaints['Complaint Type'].value_counts()
# Out:
# Noise - Residential                    1748673
# HEAT/HOT WATER                         1152592
# Street Condition                        947647
# Street Light Condition                  898738
# HEATING                                 887869
# Blocked Driveway                        882649
# Illegal Parking                         864236
# PLUMBING                                703637
# Water System                            635424
# GENERAL CONSTRUCTION                    500863
# General Construction/Plumbing           487762
# Noise                                   467069
# Noise - Street/Sidewalk                 456160
# UNSANITARY CONDITION                    438981
# Traffic Signal Condition                424454
# PAINT - PLASTER                         361258
# Sewer                                   354588
# PAINT/PLASTER                           341793
# Dirty Conditions                        340985
# Noise - Commercial                      339165
# Request Large Bulky Item Collection     326335
# ELECTRIC                                303971
# Sanitation Condition                    300764
# Damaged Tree                            284043
# Building/Use                            266564
# Rodent                                  265643
# NONCONST                                260890
# Missed Collection (All Materials)       250485
# Sidewalk Condition                      242456
# Derelict Vehicle                        207812
#                                         ...
# *)(!(objectClass=*)                          1
# Meals Home Delivery Required                 1
# Misc. Comments"|ping -...                    1
# %c0%ae/%c0%ae/%c0%ae/%c0%ae...               1
# LEAD                                         1
# Misc. Comments'+(function()...               1
# Misc. Comments';declare @q ...               1
# .../...//.../...//.../...//...               1
# Misc. Comments');declare @q...               1
# kawn''lcgv                                   1
# /etc/passwd                                  1
# Misc. Comments"|echo 2...                    1
# Misc. Comments47876391' or ...               1
# (select extractvalue(xmltyp...               1
# Misc. Comments' and '7835'=...               1
# ...\.\...\.\...\.\...\.\......               1
# Misc. Comments52038737' or ...               1
# ../WEB-INF/web.xml;x=                        1
# %E5%98%8A%E5%98%8DX-Injecti...               1
# Employee Behavior                            1
# nslookup -q=cname nneyfcxgy...               1
# ../../WEB-INF/web.xml                        1
# Misc. Comments'+(select loa...               1
# *)(objectClass=*                             1
# Asbestos/Garbage Nuisance                    1
# ...\./...\./...\./...\./......               1
# Misc. Comments' waitfor del...               1
# .../....///.../....///.../....               1
# ../../../WEB-INF/web.xml                     1
# Misc. Comments'+eval(compil...               1
# Name: Complaint Type, Length: 434, dtype: int64

# %%
# Let's clean the data a bit
# WARNING: HUGE MEMORY required
complaints = complaints[~complaints['Complaint Type'].str.contains("Misc.")]

# %% [markdown]
# How many different distinct complaints have been issued?

# %%
complaint_count = complaints['Complaint Type'].value_counts()
complaint_count[:10]
# Out:
# Noise - Residential       1748673
# HEAT/HOT WATER            1152592
# Street Condition           947647
# Street Light Condition     898738
# HEATING                    887869
# Blocked Driveway           882649
# Illegal Parking            864236
# PLUMBING                   703637
# Water System               635424
# GENERAL CONSTRUCTION       500863
# Name: Complaint Type, dtype: int64

# %%
type(complaint_count)
# Out:
# pandas.core.series.Series

# %%
complaint_count[:10].plot(kind='bar')

# %% [markdown]
# What about the `noise` complaint?

# %%
noise_complaints = complaints[complaints['Complaint Type'] == 'Noise - Street/Sidewalk']
noise_complaints[:3]
# Out:
#      Unique Key            Created Date             Closed Date Agency  \
# 248    30800567  06/08/2015 02:30:38 PM  06/09/2015 12:22:56 AM   NYPD
# 249    30800568  06/08/2015 08:35:17 PM  06/08/2015 11:20:56 PM   NYPD
# 254    30800576  06/08/2015 09:51:48 PM  06/09/2015 12:20:44 AM   NYPD
#
#                          Agency Name           Complaint Type  \
# 248  New York City Police Department  Noise - Street/Sidewalk
# 249  New York City Police Department  Noise - Street/Sidewalk
# 254  New York City Police Department  Noise - Street/Sidewalk
#
#            Descriptor    Location Type Incident Zip     Incident Address  \
# 248  Loud Music/Party  Street/Sidewalk        10451      EAST 149 STREET
# 249      Loud Talking  Street/Sidewalk        10459      1159 FOX STREET
# 254      Loud Talking  Street/Sidewalk        10456  1225 SHERMAN AVENUE
#
#                        ...                    Vehicle Type  \
# 248                    ...                             NaN
# 249                    ...                             NaN
# 254                    ...                             NaN
#
#     Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 248                  NaN                   NaN                 NaN
# 249                  NaN                   NaN                 NaN
# 254                  NaN                   NaN                 NaN
#
#     Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 248                      NaN       NaN                    NaN  40.818934
# 249                      NaN       NaN                    NaN  40.828731
# 254                      NaN       NaN                    NaN  40.834288
#
#      Longitude                                  Location
# 248 -73.928750   (40.81893427534037, -73.92875004205308)
# 249 -73.893852   (40.82873077667152, -73.89385187319155)
# 254 -73.915609  (40.834287583257066, -73.91560852329935)
#
# [3 rows x 41 columns]

# %%
# Boolean indexing of dataframe
complaints['Complaint Type'] == 'Noise - Street/Sidewalk'
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
#             ...
# 21580142    False
# 21580143    False
# 21580144    False
# 21580145    False
# 21580146     True
# 21580147    False
# 21580148    False
# 21580149    False
# 21580150    False
# 21580151    False
# 21580152    False
# 21580153    False
# 21580154    False
# 21580155    False
# 21580156    False
# 21580157    False
# 21580158    False
# 21580159    False
# 21580160    False
# 21580161    False
# 21580162    False
# 21580163    False
# 21580164    False
# 21580165    False
# 21580166    False
# 21580167    False
# 21580168    False
# 21580169    False
# 21580170    False
# 21580171    False
# Name: Complaint Type, Length: 21564523, dtype: bool

# %%
is_noise = complaints['Complaint Type'] == 'Noise - Street/Sidewalk'
in_brooklyn = complaints['Borough'] == 'BROOKLYN'
complaints[is_noise & in_brooklyn][:5]
# Out:
#      Unique Key            Created Date             Closed Date Agency  \
# 255    30800577  06/08/2015 07:23:02 PM  06/08/2015 07:38:05 PM   NYPD
# 263    30800585  06/08/2015 03:36:00 AM  06/08/2015 04:00:29 AM   NYPD
# 297    30800627  06/08/2015 11:12:35 PM  06/09/2015 12:06:54 AM   NYPD
# 324    30800690  06/08/2015 03:39:39 AM  06/08/2015 03:59:27 AM   NYPD
# 390    30800805  06/09/2015 01:03:42 AM  06/09/2015 02:16:18 AM   NYPD
#
#                          Agency Name           Complaint Type    Descriptor  \
# 255  New York City Police Department  Noise - Street/Sidewalk  Loud Talking
# 263  New York City Police Department  Noise - Street/Sidewalk  Loud Talking
# 297  New York City Police Department  Noise - Street/Sidewalk  Loud Talking
# 324  New York City Police Department  Noise - Street/Sidewalk  Loud Talking
# 390  New York City Police Department  Noise - Street/Sidewalk  Loud Talking
#
#        Location Type Incident Zip     Incident Address  \
# 255  Street/Sidewalk        11225  318 LEFFERTS AVENUE
# 263  Street/Sidewalk        11215        352 21 STREET
# 297  Street/Sidewalk        11208                  NaN
# 324  Street/Sidewalk        11215        351 21 STREET
# 390  Street/Sidewalk        11205    692 MYRTLE AVENUE
#
#                        ...                    Vehicle Type  \
# 255                    ...                             NaN
# 263                    ...                             NaN
# 297                    ...                             NaN
# 324                    ...                             NaN
# 390                    ...                             NaN
#
#     Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 255                  NaN                   NaN                 NaN
# 263                  NaN                   NaN                 NaN
# 297                  NaN                   NaN                 NaN
# 324                  NaN                   NaN                 NaN
# 390                  NaN                   NaN                 NaN
#
#     Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 255                      NaN       NaN                    NaN  40.662349
# 263                      NaN       NaN                    NaN  40.659080
# 297                      NaN       NaN                    NaN  40.681675
# 324                      NaN       NaN                    NaN  40.659088
# 390                      NaN       NaN                    NaN  40.694605
#
#      Longitude                                  Location
# 255 -73.950706   (40.66234947850847, -73.95070599835685)
# 263 -73.989677   (40.65907956566361, -73.98967745734318)
# 297 -73.879127   (40.681674670771734, -73.8791268829798)
# 324 -73.989656     (40.65908779806095, -73.989655830628)
# 390 -73.955832  (40.694605400407276, -73.95583174788501)
#
# [5 rows x 41 columns]

# %%
complaints[is_noise & in_brooklyn][['Complaint Type', 'Borough', 'Created Date']][:10]
# Out:
#                Complaint Type   Borough            Created Date
# 255   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 07:23:02 PM
# 263   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 03:36:00 AM
# 297   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 11:12:35 PM
# 324   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 03:39:39 AM
# 390   Noise - Street/Sidewalk  BROOKLYN  06/09/2015 01:03:42 AM
# 570   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 10:21:21 PM
# 859   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 06:39:39 PM
# 870   Noise - Street/Sidewalk  BROOKLYN  06/08/2015 09:24:08 PM
# 1302  Noise - Street/Sidewalk  BROOKLYN  06/08/2015 02:20:05 PM
# 1307  Noise - Street/Sidewalk  BROOKLYN  06/08/2015 10:59:44 PM

# %%
type(complaints['Created Date'])
# Out:
# pandas.core.series.Series

# %%
is_noise[:3]
# Out:
# 0    False
# 1    False
# 2    False
# Name: Complaint Type, dtype: bool

# %%
noise_complaints = complaints[is_noise]
noise_complaints['Borough'].value_counts()
# Out:
# MANHATTAN        184155
# BROOKLYN         125147
# BRONX             92142
# QUEENS            45938
# STATEN ISLAND      6509
# Unspecified        2269
# Name: Borough, dtype: int64

# %%
noise_complaints_counts = noise_complaints['Borough'].value_counts()
complaints_counts = complaints['Borough'].value_counts()

# %%
noise_complaints_counts / complaints_counts
# Out:
# BRONX            0.024551
# BROOKLYN         0.019519
# MANHATTAN        0.044081
# QUEENS           0.009339
# STATEN ISLAND    0.006015
# Unspecified      0.001858
# Name: Borough, dtype: float64

# %%
complaints_counts[:3]
# Out:
# BROOKLYN     6411662
# QUEENS       4918743
# MANHATTAN    4177659
# Name: Borough, dtype: int64

# %%
noise_complaints_counts / complaints_counts.astype(float)
# Out:
# BRONX            0.024551
# BROOKLYN         0.019519
# MANHATTAN        0.044081
# QUEENS           0.009339
# STATEN ISLAND    0.006015
# Unspecified      0.001858
# Name: Borough, dtype: float64

# %%
(noise_complaints_counts / complaints_counts.astype(float)).plot(kind='bar')
