# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (15, 5)

# %%
complaints = pd.read_csv('311_small.csv')
# Out:
# /var/folders/b3/cjvms6c10k77tgv6k_rw3jbh0000gn/T/ipykernel_51022/3601407749.py:1: DtypeWarning: Columns (8,31,32,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv('311_small.csv')

# %%
complaints.iloc[:, [8,31,32,34,35,36,37]].columns
# Out:
# Index(['Incident Zip', 'Vehicle Type', 'Taxi Company Borough',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
#        'Bridge Highway Segment'],
#       dtype='object')

# %%
complaints['Incident Zip'].dtype
# Out:
# dtype('O')

# %%
complaints['Complaint Type'].unique()
# Out:
# array(['HEAT/HOT WATER', 'HPD Literature Request', 'Smoking',
#        'Sidewalk Condition', 'Damaged Tree', 'Street Condition',
#        'Street Light Condition', 'General Construction/Plumbing',
#        'Plumbing', 'Curb Condition', 'Animal Abuse',
#        'Non-Residential Heat', 'Electronics Waste',
#        'Traffic Signal Condition', 'Water System', 'APPLIANCE',
#        'DOOR/WINDOW', 'Food Poisoning', 'Street Sign - Damaged',
#        'Noise - Vehicle', 'Street Sign - Missing', 'Food Establishment',
#        'Electrical', 'ELECTRIC', 'New Tree Request', 'Noise',
#        'FLOORING/STAIRS', 'GENERAL', 'Root/Sewer/Sidewalk Condition',
#        'Dead/Dying Tree', 'DOF Property - Reduction Issue',
#        'DOF Property - Payment Issue', 'Traffic', 'Graffiti',
#        'DOF Parking - Request Copy', 'SAFETY',
#        'DOF Parking - Payment Issue', 'Illegal Parking',
#        'DOF Parking - Request Status', 'Broken Muni Meter',
#        'Taxi Complaint', 'Noise - Residential', 'Blocked Driveway',
#        'Snow', 'Dirty Conditions', 'Sweeping/Inadequate',
#        'Noise - Commercial', 'Indoor Sewage', 'Ferry Complaint',
#        'Hazardous Materials', 'Derelict Vehicle',
#        'DOF Property - Owner Issue', 'Water Conservation',
#        'Non-Emergency Police Matter', 'Rodent',
#        'Homeless Person Assistance', 'Sanitation Condition',
#        'Drug Activity', 'PAINT/PLASTER', 'DOF Property - Request Copy',
#        'PLUMBING', 'Consumer Complaint', 'Maintenance or Facility',
#        'DRIE', 'UNSANITARY CONDITION', 'Taxi Report',
#        'Indoor Air Quality', 'WATER LEAK', 'Street Sign - Dangling',
#        'Vacant Lot', 'Highway Condition',
#        'Request Large Bulky Item Collection', 'Noise - Street/Sidewalk',
#        'Building/Use', 'Ferry Inquiry', 'Drinking',
#        'Broken Parking Meter', 'Taxi Compliment', 'LinkNYC',
#        'Housing - Low Income Senior', 'Question', 'Boilers',
#        'Special Projects Inspection Team (SPIT)', 'Air Quality', 'Sewer',
#        'Panhandling', 'ELEVATOR', 'Overgrown Tree/Branches',
#        'For Hire Vehicle Complaint', 'Lead', 'Water Quality',
#        'DPR Internal', 'Animal in a Park', 'Other Enforcement',
#        'Asbestos', 'OUTSIDE BUILDING',
#        'Missed Collection (All Materials)', 'Illegal Tree Damage',
#        'Bus Stop Shelter Complaint', 'Homeless Encampment',
#        'Litter Basket / Request', 'Private or Charter School Reopening',
#        'Sweeping/Missed', 'FCST', 'Unsanitary Pigeon Condition',
#        'Unsanitary Animal Pvt Property', 'Standing Water', 'Elevator',
#        'Violation of Park Rules', 'Bus Stop Shelter Placement',
#        'Housing Options', 'Drinking Water', 'Mold',
#        'DOF Parking - Tax Exemption', 'Pet Shop',
#        'Overflowing Litter Baskets', 'Industrial Waste',
#        'Bridge Condition', 'NonCompliance with Phased Reopening',
#        'School Maintenance', 'Construction', 'For Hire Vehicle Report',
#        'Case Management Agency Complaint', 'Forms',
#        'DOF Property - RPIE Issue', 'Day Care',
#        'Public Payphone Complaint', 'OEM Literature Request',
#        'Bike/Roller/Skate Chronic', 'Highway Sign - Missing',
#        'Posting Advertisement', 'Noise - Helicopter', 'Vending',
#        'Advocate - Other', 'Unleashed Dog', 'Noise - House of Worship',
#        'DOF Parking - DMV Clearance', 'SCRIE',
#        'Home Delivered Meal - Missed Delivery', 'BEST/Site Safety',
#        'DCA / DOH New License Application Request',
#        'Benefit Card Replacement', 'DOF Property - Update Account',
#        'Noise - Park', 'Derelict Vehicles', 'Lifeguard',
#        'Senior Center Complaint', 'Advocate-Personal Exemptions',
#        'Dead Tree', 'Beach/Pool/Sauna Complaint', 'Encampment',
#        'Animal Facility - No Permit', 'Collection Truck Noise',
#        'Found Property', 'Emergency Response Team (ERT)',
#        'Derelict Bicycle', 'Ferry Permit', 'Traffic/Illegal Parking',
#        'DHS Income Savings Requirement', 'Lost Property',
#        'NORC Complaint', 'DOF Property - Property Value',
#        'Abandoned Vehicle', 'Disorderly Youth', 'Tattooing',
#        'Illegal Animal Sold', 'Window Guard', 'Plant',
#        'Illegal Animal Kept as Pet', 'Illegal Fireworks',
#        'Bike Rack Condition', 'Mass Gathering Complaint', 'Animal-Abuse',
#        'Urinating in Public', 'DHS Advantage -Landlord/Broker',
#        'Parking Card', 'ATF', 'Scaffold Safety',
#        'Municipal Parking Facility', 'Taxpayer Advocate Inquiry', 'Storm',
#        'Highway Sign - Damaged', 'City Vehicle Placard Complaint',
#        'Unsanitary Animal Facility', "Alzheimer's Care",
#        'Tunnel Condition', 'Transportation Provider Complaint',
#        'Bereavement Support Group', 'Public Toilet',
#        'Advocate-Co-opCondo Abatement', 'Recycling Enforcement', 'FATF',
#        'Adopt-A-Basket', 'DHS Advantage - Tenant',
#        'Investigations and Discipline (IAD)',
#        'Advocate-Prop Refunds/Credits', 'Cranes and Derricks',
#        'Sweeping/Missed-Inadequate', 'Outdoor Dining',
#        'Research Questions', 'Dirty Condition', 'Harboring Bees/Wasps',
#        'Advocate-Commercial Exemptions', 'Select Message Type...',
#        'Elder Abuse', 'Illegal Dumping', 'Poison Ivy',
#        'Special Enforcement', 'Missed Collection',
#        'Home Delivered Meal Complaint', 'Mobile Food Vendor',
#        'Radioactive Material', 'Special Natural Area District (SNAD)',
#        'Electronics Waste Appointment', 'Home Repair', 'Summer Camp',
#        'Legal Services Provider Complaint',
#        'Request Xmas Tree Collection', 'Advocate-Property Value', 'SNW',
#        'Highway Sign - Dangling', 'DOF Property - City Rebate',
#        'Construction Lead Dust', 'Comments',
#        'Institution Disposal Complaint', 'Weatherization', 'Tanning',
#        'X-Ray Machine/Equipment', 'Calorie Labeling', 'Bottled Water',
#        'Injured Wildlife', 'Miscellaneous Categories',
#        'Homeless Street Condition', 'General Question',
#        'Illegal Animal - Sold/Kept', 'Homebound Evacuation 4',
#        'Cooling Tower', 'Stalled Sites', 'Mosquitoes',
#        'No Child Left Behind', 'Green Taxi Complaint',
#        'Residential Disposal Complaint', 'Street Sweeping Complaint',
#        'Dead Animal', 'Overflowing Recycling Baskets', 'Uprooted Stump',
#        'Litter Basket Request', 'Building Condition', 'Advocate - Lien',
#        'Home Care Provider Complaint', 'Advocate - Levy', 'Peeling Paint',
#        'Trans Fat'], dtype=object)

# %%
complaints[['Complaint Type', 'Borough']][:10]
# Out:
#                   Complaint Type        Borough
# 0                 HEAT/HOT WATER       BROOKLYN
# 1         HPD Literature Request    Unspecified
# 2                        Smoking       BROOKLYN
# 3             Sidewalk Condition      MANHATTAN
# 4                   Damaged Tree  STATEN ISLAND
# 5               Street Condition          BRONX
# 6               Street Condition  STATEN ISLAND
# 7               Street Condition  STATEN ISLAND
# 8         Street Light Condition       BROOKLYN
# 9  General Construction/Plumbing         QUEENS

# %%
complaints_counts = complaints['Complaint Type'].value_counts()

# %%
type(complaints_counts)
# Out:
# pandas.core.series.Series

# %%
complaints_counts[:10]
# Out:
# Complaint Type
# HEAT/HOT WATER                         124358
# Noise - Residential                     83272
# General Construction/Plumbing           57295
# Illegal Parking                         56634
# Request Large Bulky Item Collection     54515
# Blocked Driveway                        51171
# Street Condition                        47301
# Water System                            28549
# Street Light Condition                  26744
# UNSANITARY CONDITION                    25171
# Name: count, dtype: int64

# %%
complaints_counts[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='Complaint Type'>

# %%
noise_complaints = complaints[complaints['Complaint Type'] == 'Noise - Residential']

# %%
noise_complaints.shape
# Out:
# (83272, 41)

# %%
is_noise = complaints['Complaint Type'] == 'Noise - Residential'

# %%
is_brooklyn = complaints['Borough'] == 'BROOKLYN'

# %%
complaints[is_noise & is_brooklyn].shape
# Out:
# (23083, 41)

# %%
complaints['Borough'].value_counts()
# Out:
# Borough
# BROOKLYN         322885
# QUEENS           240326
# BRONX            182361
# MANHATTAN        181866
# STATEN ISLAND     53961
# Unspecified       18502
# Name: count, dtype: int64

# %%
complaints[is_noise & is_brooklyn][['Created Date', 'Incident Zip']]
# Out:
#                   Created Date Incident Zip
# 341     12/28/2017 06:52:56 PM        11205
# 660     02/23/2013 12:38:24 AM        11206
# 951     12/28/2017 09:56:02 PM        11207
# 956     12/28/2017 03:07:39 PM        11206
# 959     12/28/2017 09:23:11 PM        11207
# ...                        ...          ...
# 999710  05/14/2018 11:33:45 PM      11229.0
# 999743  05/14/2018 08:43:58 PM      11220.0
# 999750  05/14/2018 06:52:12 PM      11234.0
# 999753  05/15/2018 12:04:38 AM      11218.0
# 999850  05/15/2018 01:15:18 AM      11206.0
#
# [23083 rows x 2 columns]

# %%
complaints_counts = complaints['Borough'].value_counts()

# %%
noise_complaints = complaints[is_noise]

# %%
noise_complaints_counts = noise_complaints['Borough'].value_counts()

# %%
complaints_counts
# Out:
# Borough
# BROOKLYN         322885
# QUEENS           240326
# BRONX            182361
# MANHATTAN        181866
# STATEN ISLAND     53961
# Unspecified       18502
# Name: count, dtype: int64

# %%
noise_complaints_counts / complaints_counts
# Out:
# Borough
# BRONX            0.125767
# BROOKLYN         0.071490
# MANHATTAN        0.113991
# QUEENS           0.059415
# STATEN ISLAND    0.040881
# Unspecified      0.002054
# Name: count, dtype: float64

# %%
(noise_complaints_counts / complaints_counts).plot(kind='bar')
# Out:
# <Axes: xlabel='Borough'>

# %%
complaints['Incident Zip'].astype(int).value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 complaints['Incident Zip'].astype(int).value_counts()
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %%
zips = complaints['Incident Zip']

# %%
zips.isna().sum()
# Out:
# 88509

# %%
zips.dropna().astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 zips.dropna().astype(int)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '37214-0065'

# %%
import numpy as np

def clean_zipcode(x):
    try:
        res = int(x)
    except ValueError:  # either float or nan
        if np.isnan(x):
            res = -1
        else:
            try:
                res = int(x.split('-')[0])
            except:
                res = 0
                
    return res

# %%
zips.apply(lambda x: clean_zipcode(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in clean_zipcode(x)
#       4 try:
# ----> 5     res = int(x)
#       6 except ValueError:  # either float or nan
#
# ValueError: invalid literal for int() with base 10: '37214-0065'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 zips.apply(lambda x: clean_zipcode(x))
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Input In [70], in <lambda>(x)
# ----> 1 zips.apply(lambda x: clean_zipcode(x))
#
# Input In [68], in clean_zipcode(x)
#       5     res = int(x)
#       6 except ValueError:  # either float or nan
# ----> 7     if np.isnan(x):
#       8         res = -1
#       9     else:
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
np.isnan('123')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 np.isnan('123')
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
