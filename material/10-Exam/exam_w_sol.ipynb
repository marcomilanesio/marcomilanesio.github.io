# %% [markdown]
# # **Final Exam**
# ### Technologies for Big Data with Python3
#
# ### **NOTICE**
# This notebook is composed by a set of short exercises and questions spanning through the content of the course (up until the `timeseries` topic, excluded).
# It is divided into three parts:
#
#
# 1.   Basic Python3
# 2.   Spark RDD and Dataframe
# 3.   Machine Learning
#
# For each part, a set of resources is given to help you fulfilling the tasks.
#
# Add as many code cell as you need, and also some text cells when you think it's important to explain your thoughts.
#
# **IMPORTANT** Rename the notebook with your surname, download it and send it to `marco.milanesio@univ-cotedazur.fr`.

# %%
# USUAL PREAMBLE: RUN THIS CELL
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# !pip install pyspark
# Out:
# openjdk version "1.8.0_222"
# OpenJDK Runtime Environment (build 1.8.0_222-8u222-b10-1ubuntu1~18.04.1-b10)
# OpenJDK 64-Bit Server VM (build 25.222-b10, mixed mode)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.6/dist-packages (2.4.4)
# Requirement already satisfied: py4j==0.10.7 in /usr/local/lib/python3.6/dist-packages (from pyspark) (0.10.7)

# %% [markdown]
# # PART 1: Python3, numpy and pandas
#
# *   [Standard library](https://docs.python.org/3.6/library/)
# *   [numpy](https://docs.scipy.org/doc/numpy/reference/)
# *   [pandas](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# ## 1.1.
# Write a function `is_leap(year)` that check if a given year is leap or not. ([info](https://en.wikipedia.org/wiki/Leap_year))

# %%
def is_leap(year):
  """
  Check if 'year` is leap or not
  @param year: integer
  @return boolean
  """
  # write here your code
  if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    return True
  return False

# %%
# TESTING CELL: DO NOT MODIFY
# run this cell to check if your code works properly: if so, no output will show up
assert is_leap(1980)
assert not is_leap(1977)
assert is_leap(2000)
assert not is_leap(2001)

# %% [markdown]
# ## 1.2.
# Write a function `can_form_valid_triangle(list_of_lengths)` that checks if a given set of `lengths` can form a valid triangle and of which type (equilateral, isosceles, scalene).
#
# *hint*: all permutations of the three lengths (`n = 3; lengths = [a,b,c]`) must satisfy the "triangle inequality" (e.g., `a < b + c`)

# %%
def can_form_valid_triangle(list_of_lengths):
  """
  Inspect a list of lengths to check if it's a valid triangle or not
  @param list_of_lengths: a list of integers
  @return Type of triangle (if it's a valid triangle) or False
  """
  result = False
  if len(list_of_lengths) > 3:
    return result
  a, b, c = list_of_lengths
  if a < b + c and b < a + c and c < a + b:
    if a == b == c:
      result = 'equilateral'
    elif len(set([x for x in list_of_lengths])) == 2:
      result = 'isosceles'
    else:
      result = 'scalene'
  return result

# %%
# TESTING CELL: DO NOT MODIFY
# run this cell to check if your code works properly: if so, no output will show up
assert can_form_valid_triangle([3,4,5]) == 'scalene'
assert not can_form_valid_triangle([1,3,4])
assert not can_form_valid_triangle([1,3,10])
assert can_form_valid_triangle([7,10,5])
assert can_form_valid_triangle([3,3,3]) == 'equilateral'
assert can_form_valid_triangle([6,6,3]) == 'isosceles'

# %% [markdown]
# ## 1.3.
# Given the `numpy.array` `z` negate all elements `x` such that `3 < x <= 8`
#
# *Note*: Boolean Series are combined using the `bitwise`, rather than the traditional boolean operators. For example, when performing logical and, use `&` instead of `and`.

# %%
import numpy as np
z = np.arange(11)
# write here your code
z[(3 < z) & (z <= 8)] *= -1

# %%
# TESTING CELL: DO NOT MODIFY
# run this cell to check if your code works properly: if so, no output will show up
assert np.sum(z) == -5
assert z[5] == -5

# %% [markdown]
# ## 1.4.
# Given the following `pandas` `Dataframe`:

# %%
import pandas as pd
city_names = pd.Series(['San Francisco', 'San Jose', 'Sacramento'])
population = pd.Series([852469, 1015785, 485199])
cities = pd.DataFrame({'City name': city_names, 'Population': population})

cities['Area square miles'] = pd.Series([46.87, 176.53, 97.92])
cities['Population density'] = cities['Population'] / cities['Area square miles']
cities
# Out:
#        City name  Population  Area square miles  Population density
# 0  San Francisco      852469              46.87        18187.945381
# 1       San Jose     1015785             176.53         5754.177760
# 2     Sacramento      485199              97.92         4955.055147

# %% [markdown]
# Modify the `cities` table by adding a new `boolean` column that is `True` if and only if both of the following are True:
#
# *    The city is named after a saint.
# *    The city has an area greater than 50 square miles.
#
# *Hint*: "San" in Spanish means "saint."

# %%
# write here your code
cities['Is wide and has saint name'] = (cities['Area square miles'] > 50) & cities['City name'].apply(lambda name: name.startswith('San'))
cities
# Out:
#        City name  Population  ...  Population density  Is wide and has saint name
# 0  San Francisco      852469  ...        18187.945381                       False
# 1       San Jose     1015785  ...         5754.177760                        True
# 2     Sacramento      485199  ...         4955.055147                       False
#
# [3 rows x 5 columns]

# %%
# TESTING CELL: DO NOT MODIFY
# run this cell to check if your code works properly: if so, no output will show up
assert all(cities['Is wide and has saint name'] == pd.Series([False, True, False]))

# %% [markdown]
# # PART 2: Pyspark
#
# *  [Pyspark API](https://spark.apache.org/docs/latest/api/python/index.html)
# *  [Learning Apache Spark](https://runawayhorse001.github.io/LearningApacheSpark/index.html)

# %%
# RUN THIS CELL BEFORE PROCEEDING
# pyspark-related imports
from pyspark.sql import SparkSession, SQLContext

# %% [markdown]
# ## 2.1
#
# Create a spark session object `spark` named `'exam'`, extract the spark context.

# %%
spark = SparkSession.builder.appName('exam').getOrCreate()  # the base spark session for this exam
sc = spark.sparkContext  # the spark context attached to the session

# %%
# TESTING CELL: DO NOT MODIFY
# run this cell to check if your code works properly: if so, no output will show up
from pyspark.context import SparkContext
assert type(sc) == SparkContext

# %% [markdown]
# ### 2.2
# Using the RDD api,
#
# *   parallelize the given list
# *   sum all odd elements

# %%
# RUN THIS CELL
np.random.seed(1234) # for reproducibility
data = np.random.randint(100, size=25)

# %%
# write here your code
rdd = sc.parallelize(data)
result = rdd.filter(lambda x: x % 2 == 1).sum()

# %%
# TESTING CELL: DO NOT MODIFY
# run this cell to check if your code works properly: if so, no output will show up
assert result == 539

# %% [markdown]
# # PART 3: Machine Learning

# %%
# Execute this cell to generate the data needed.
import matplotlib.pyplot as plt

np.random.seed(10)
X = np.random.uniform(low=-180, high=180, size=(800,))  # pay attention to the used distribution
Y = np.random.uniform(low=-90, high=90, size=(800,))  # pay attention to the used distribution
df = pd.DataFrame(pd.DataFrame(dict(x=X, y=Y)))
df.plot(kind='scatter',x='x',y='y',color='black')
plt.show()

# %% [markdown]
# ## 3.1
# Create a `Spark` Dataframe using the `df` dataframe defined in previous cell.
#
# *hint* you'll need a sqlcontext to to this...

# %%
# write here your code
sqlContext = SQLContext(sc)
sdf = sqlContext.createDataFrame(df)

# %% [markdown]
# ## 3.2
# Create a KMeans model on `sdf`, with `k = 4`.
# Show the population in each cluster and the total cost on the final clustering.
#
# *hint*: being the coordinates quite different between each other it will be better to scale them using a `StandardScaler`.

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler

# write here your code
vec_assembler = VectorAssembler(inputCols =['x', 'y'], outputCol='features')
final_data = vec_assembler.transform(sdf)
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures", withStd=True, withMean=False)
scalerModel = scaler.fit(final_data)
cluster_final_data = scalerModel.transform(final_data)
kmeans4 = KMeans(featuresCol='scaledFeatures',k=4)
model_k4 = kmeans4.fit(cluster_final_data)
wssse_k4 = model_k4.computeCost(cluster_final_data)
model_k4.transform(cluster_final_data).groupBy('prediction').count().show()
print(wssse_k4)
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|  229|
# |         3|  195|
# |         2|  180|
# |         0|  196|
# +----------+-----+
#
# 379.4184911661381

# %% [markdown]
# Is it good or bad?
# Try with different number of `k` to check if there is a better clustering.
#
# *hint* for example, you can check the relative sizes for the different clusters.
# *hint* you can access each Row by importing the `Row` module.

# %%
from pyspark.sql import Row

# write here your code
for k in range(2, 9):
  kmeans = KMeans(featuresCol='scaledFeatures',k=k)
  model = kmeans.fit(cluster_final_data)
  wssse = model.computeCost(cluster_final_data)
  result = model.transform(cluster_final_data).groupBy('prediction').count()
  print('wssse for k = ', k, ' :', wssse)
  result.show()
  counts = result.select('count').collect()
  print(max([r['count'] for r in counts]) - min([r['count'] for r in counts]))
  print('-------------')
# Out:
# wssse for k =  2  : 989.7181694588764
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|  411|
# |         0|  389|
# +----------+-----+
#
# 22
# -------------
# wssse for k =  3  : 636.934731377996
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|  290|
# |         2|  250|
# |         0|  260|
# +----------+-----+
#
# 40
# -------------
# wssse for k =  4  : 379.4184911661381
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|  229|
# |         3|  195|
# |         2|  180|
# |         0|  196|
# +----------+-----+
#
# 49
# -------------
# wssse for k =  5  : 319.14714529808566
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|  140|
# |         3|  183|
# |         4|  135|
# |         2|  183|
# |         0|  159|
# +----------+-----+
#
# 48
# -------------
# wssse for k =  6  : 271.62264951265934
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|  152|
# |         3|  109|
# |         5|  141|
# |         4|  129|
# |         2|  174|
# |         0|   95|
# +----------+-----+
#
# 79
# -------------
# wssse for k =  7  : 231.63920874150602
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|   96|
# |         6|  112|
# |         3|  113|
# |         5|  122|
# |         4|   98|
# |         2|  105|
# |         0|  154|
# +----------+-----+
#
# 58
# -------------
# wssse for k =  8  : 194.82009294032204
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |         1|   96|
# |         6|   93|
# |         3|   86|
# |         5|  109|
# |         4|  124|
# |         7|   80|
# |         2|  115|
# |         0|   97|
# +----------+-----+
#
# 44
# -------------
